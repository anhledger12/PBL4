# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
# i = []
# for k in range(1, 10):
#     i.append(k)
i = np.arange(1, 10, 1)
print(i)
# x = []
# for j in i:
#     x.append(20 * math.cos(2 * math.pi * j + math.pi * 0.12))
# print(x)
# plt.plot(x)
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
T_1 = 5
T_2 = 6
x1 = np.cos(2 * np.pi *)
